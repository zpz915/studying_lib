# %%
import tensorflow as tf #参考vgg 那里的书写

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pathlib

# %%
data_dir = "/home/mi/zpz/xuexi/多输出模型数据集（同时预测物品和颜色）/multi-output-classification/dataset"

# %%
data_root = pathlib.Path(data_dir)

# %%
data_root
# Out:
# PosixPath('/home/mi/zpz/xuexi/多输出模型数据集（同时预测物品和颜色）/multi-output-classification/dataset')

# %%
for item in data_root.iterdir():
    print(item)
# Out:
# /home/mi/zpz/xuexi/多输出模型数据集（同时预测物品和颜色）/multi-output-classification/dataset/black_jeans
# /home/mi/zpz/xuexi/多输出模型数据集（同时预测物品和颜色）/multi-output-classification/dataset/blue_dress
# /home/mi/zpz/xuexi/多输出模型数据集（同时预测物品和颜色）/multi-output-classification/dataset/black_shoes
# /home/mi/zpz/xuexi/多输出模型数据集（同时预测物品和颜色）/multi-output-classification/dataset/red_shirt
# /home/mi/zpz/xuexi/多输出模型数据集（同时预测物品和颜色）/multi-output-classification/dataset/blue_shirt
# /home/mi/zpz/xuexi/多输出模型数据集（同时预测物品和颜色）/multi-output-classification/dataset/red_dress
# /home/mi/zpz/xuexi/多输出模型数据集（同时预测物品和颜色）/multi-output-classification/dataset/blue_jeans

# %%
all_image_paths = list(data_root.glob("*/*"))

# %%
image_count = len(all_image_paths)
image_count
# Out:
# 2525

# %%
all_image_paths[:3]
# Out:
# [PosixPath('/home/mi/zpz/xuexi/多输出模型数据集（同时预测物品和颜色）/multi-output-classification/dataset/black_jeans/00000199.jpg'),
#  PosixPath('/home/mi/zpz/xuexi/多输出模型数据集（同时预测物品和颜色）/multi-output-classification/dataset/black_jeans/00000090.jpg'),
#  PosixPath('/home/mi/zpz/xuexi/多输出模型数据集（同时预测物品和颜色）/multi-output-classification/dataset/black_jeans/00000222.JPG')]

# %%
all_image_paths[-3:]
# Out:
# [PosixPath('/home/mi/zpz/xuexi/多输出模型数据集（同时预测物品和颜色）/multi-output-classification/dataset/blue_jeans/00000020.jpg'),
#  PosixPath('/home/mi/zpz/xuexi/多输出模型数据集（同时预测物品和颜色）/multi-output-classification/dataset/blue_jeans/00000184.jpeg'),
#  PosixPath('/home/mi/zpz/xuexi/多输出模型数据集（同时预测物品和颜色）/multi-output-classification/dataset/blue_jeans/00000017.jpg')]

# %%
import random
all_image_paths = [str(path) for path in all_image_paths]
random.shuffle(all_image_paths)  #随机常见的路径形式

# %%
all_image_paths[:5]
# Out:
# ['/home/mi/zpz/xuexi/多输出模型数据集（同时预测物品和颜色）/multi-output-classification/dataset/black_shoes/00000104.jpg',
#  '/home/mi/zpz/xuexi/多输出模型数据集（同时预测物品和颜色）/multi-output-classification/dataset/red_dress/00000044.jpg',
#  '/home/mi/zpz/xuexi/多输出模型数据集（同时预测物品和颜色）/multi-output-classification/dataset/black_jeans/00000214.jpg',
#  '/home/mi/zpz/xuexi/多输出模型数据集（同时预测物品和颜色）/multi-output-classification/dataset/red_dress/00000098.jpg',
#  '/home/mi/zpz/xuexi/多输出模型数据集（同时预测物品和颜色）/multi-output-classification/dataset/blue_jeans/00000143.jpeg']

# %%
label_names = sorted(item.name for item in data_root.glob("*/") if item.is_dir())
label_names #提取标签值
# Out:
# ['black_jeans',
#  'black_shoes',
#  'blue_dress',
#  'blue_jeans',
#  'blue_shirt',
#  'red_dress',
#  'red_shirt']

# %%
#因为两个标签值 所以分开
color_label_names = set(name.split("_")[0] for name in label_names)
color_label_names
# Out:
# {'black', 'blue', 'red'}

# %%
item_label_names = set(name.split("_")[1] for name in label_names)  #用glob方法更方便
item_label_names
# Out:
# {'dress', 'jeans', 'shirt', 'shoes'}

# %%
#标签和索引的相互转换
color_label_to_index = dict((name,index) for index,name in enumerate(color_label_names))
color_label_to_index
# Out:
# {'red': 0, 'blue': 1, 'black': 2}

# %%
item_label_to_index = dict((name,index) for index,name in enumerate(item_label_names))
item_label_to_index
# Out:
# {'jeans': 0, 'shirt': 1, 'dress': 2, 'shoes': 3}

# %%
all_image_labels = [pathlib.Path(path).parent.name for path in all_image_paths]
all_image_labels[:5]
# Out:
# ['black_shoes', 'red_dress', 'black_jeans', 'red_dress', 'blue_jeans']

# %%
color_labels = [color_label_to_index[label.split("_")[0]] for label in all_image_labels]

# %%
color_labels[:5]
# Out:
# [2, 0, 2, 0, 1]

# %%
item_labels = [item_label_to_index[label.split("_")[1]] for label in all_image_labels]

# %%
item_labels[:5]
# Out:
# [3, 2, 0, 2, 0]

# %%
import IPython.display as display

# %%
for n in range(3):
    image_index = random.choice(range(len(all_image_paths)))
    display.display(display.Image(all_image_paths[image_index],width=100,height=100))
    print(all_image_labels[image_index])
    print()
# Out:
# red_dress
# black_shoes
# black_jeans

# %%
#加载图像
img_path = all_image_paths[0]
img_path
# Out:
# '/home/mi/zpz/xuexi/多输出模型数据集（同时预测物品和颜色）/multi-output-classification/dataset/black_shoes/00000104.jpg'

# %%
img_raw = tf.io.read_file(img_path)
print(repr(img_raw)[:100]+"...")
# Out:
# <tf.Tensor: id=1, shape=(), dtype=string, numpy=b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x...
# 2021-11-19 14:28:10.118738: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2021-11-19 14:28:10.118758: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-11-19 14:28:10.118770: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (mi-HP-ProDesk-680-G6-PCI-Microtower-PC): /proc/driver/nvidia/version does not exist
# 2021-11-19 14:28:10.118921: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# 2021-11-19 14:28:10.142813: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2899885000 Hz
# 2021-11-19 14:28:10.143347: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55fd274dbc70 executing computations on platform Host. Devices:
# 2021-11-19 14:28:10.143364: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): Host, Default Version

# %%
img_tensor = tf.image.decode_image(img_raw)

# %%
img_tensor = tf.cast(img_tensor,tf.float32)
img_tensor = tf.image.resize(img_tensor,[224,224])
img_final = img_tensor/255.0
print(img_final.shape)
print(img_final.numpy().min())
print(img_final.numpy().max())
# Out:
# (224, 224, 3)
# 0.007957039
# 1.0

# %%
def load_and_preprocess_image(path):
    image = tf.io.read_file(path)
    image = tf.image.decode_jpeg(image,channels=3)
    image = tf.image.resize(image,[224,224])
    image = tf.cast(image,tf.float32)
    image = image/255.0
    image = 2*image-1
    return image

# %%
import matplotlib.pyplot as plt

image_path = all_image_paths[0]
label = all_image_labels[0]
plt.imshow((load_and_preprocess_image(img_path)+1)/2)
plt.grid(False)
plt.xlabel(label)
print()

# %%
path_ds = tf.data.Dataset.from_tensor_slices(all_image_paths)

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
image_ds = path_ds.map(load_and_preprocess_image,num_parallel_calls=AUTOTUNE)
# Out:
# WARNING:tensorflow:Entity <function load_and_preprocess_image at 0x7f393a6dd830> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: No module named 'tensorflow_core.estimator'
# WARNING: Entity <function load_and_preprocess_image at 0x7f393a6dd830> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: No module named 'tensorflow_core.estimator'

# %%
label_ds = tf.data.Dataset.from_tensor_slices((color_labels,item_labels))

# %%
for ele in label_ds.take(3):
    print(ele[0].numpy(),ele[1].numpy())
# Out:
# 2 3
# 0 2
# 2 0

# %%
image_label_ds = tf.data.Dataset.zip((image_ds,label_ds))

# %%
test_count = int(image_count*0.2)
train_count = image_count - test_count

# %%
train_data = image_label_ds.skip(test_count)
test_data = image_label_ds.take(test_count)

# %%
BATCH_SIZE = 32

# %%
train_data = train_data.shuffle(buffer_size=train_count).repeat()
train_data = train_data.batch(BATCH_SIZE)
train_data = train_data.prefetch(buffer_size=AUTOTUNE)
train_data
# Out:
# <PrefetchDataset shapes: ((None, 224, 224, 3), ((None,), (None,))), types: (tf.float32, (tf.int32, tf.int32))>

# %%
test_data = test_data.batch(BATCH_SIZE)

# %%
base_model=tf.keras.applications.mobilenet_v2.MobileNetV2(include_top=False,input_shape=(224,224,3))
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 99
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3444, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_27322/4283509473.py", line 1, in <module>
#     base_model=tf.keras.applications.mobilenet_v2.MobileNetV2(include_top=False,input_shape=(224,224,3))
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/tensorflow_core/python/keras/applications/__init__.py", line 49, in wrapper
#     return base_fun(*args, **kwargs)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/tensorflow_core/python/keras/applications/mobilenet_v2.py", line 32, in MobileNetV2
#     return mobilenet_v2.MobileNetV2(*args, **kwargs)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/keras_applications/mobilenet_v2.py", line 418, in MobileNetV2
#     model.load_weights(weights_path)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training.py", line 181, in load_weights
#     return super(Model, self).load_weights(filepath, by_name)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/network.py", line 1177, in load_weights
#     saving.load_weights_from_hdf5_group(f, self.layers)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/tensorflow_core/python/keras/saving/hdf5_format.py", line 651, in load_weights_from_hdf5_group
#     original_keras_version = f.attrs['keras_version'].decode('utf8')
# AttributeError: 'str' object has no attribute 'decode'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2064, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'AttributeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/tensorflow/__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/tensorflow/__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.estimator'
# Traceback (most recent call last):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3444, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_27322/4283509473.py", line 1, in <module>
#     base_model=tf.keras.applications.mobilenet_v2.MobileNetV2(include_top=False,input_shape=(224,224,3))
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/tensorflow_core/python/keras/applications/__init__.py", line 49, in wrapper
#     return base_fun(*args, **kwargs)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/tensorflow_core/python/keras/applications/mobilenet_v2.py", line 32, in MobileNetV2
#     return mobilenet_v2.MobileNetV2(*args, **kwargs)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/keras_applications/mobilenet_v2.py", line 418, in MobileNetV2
#     model.load_weights(weights_path)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training.py", line 181, in load_weights
#     return super(Model, self).load_weights(filepath, by_name)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/network.py", line 1177, in load_weights
#     saving.load_weights_from_hdf5_group(f, self.layers)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/tensorflow_core/python/keras/saving/hdf5_format.py", line 651, in load_weights_from_hdf5_group
#     original_keras_version = f.attrs['keras_version'].decode('utf8')
# AttributeError: 'str' object has no attribute 'decode'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2064, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'AttributeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3364, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3461, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2067, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1125, in structured_traceback
#     tb_offset)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2064, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/tensorflow/__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/tensorflow/__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.estimator'
# Traceback (most recent call last):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3444, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_27322/4283509473.py", line 1, in <module>
#     base_model=tf.keras.applications.mobilenet_v2.MobileNetV2(include_top=False,input_shape=(224,224,3))
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/tensorflow_core/python/keras/applications/__init__.py", line 49, in wrapper
#     return base_fun(*args, **kwargs)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/tensorflow_core/python/keras/applications/mobilenet_v2.py", line 32, in MobileNetV2
#     return mobilenet_v2.MobileNetV2(*args, **kwargs)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/keras_applications/mobilenet_v2.py", line 418, in MobileNetV2
#     model.load_weights(weights_path)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training.py", line 181, in load_weights
#     return super(Model, self).load_weights(filepath, by_name)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/network.py", line 1177, in load_weights
#     saving.load_weights_from_hdf5_group(f, self.layers)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/tensorflow_core/python/keras/saving/hdf5_format.py", line 651, in load_weights_from_hdf5_group
#     original_keras_version = f.attrs['keras_version'].decode('utf8')
# AttributeError: 'str' object has no attribute 'decode'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2064, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'AttributeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3364, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3461, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2067, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1125, in structured_traceback
#     tb_offset)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2064, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2947, in _run_cell
#     return runner(coro)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3173, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3383, in run_ast_nodes
#     self.showtraceback()
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2067, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1143, in structured_traceback
#     chained_exceptions_tb_offset)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2064, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/tensorflow/__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/tensorflow/__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.estimator'

# %%
#建立模型
inputs = tf.keras.Input(shape=(224,224,3))

# %%
x = mobile_net(inputs)  #输出形状是4维的
x.get_shape()
x = tf.keras.layers.GlobalAveragePooling2D() #全局取平均得到2维数据
x1 = tf.keras.layers.Desnse(1024,activation="relu")(x)
out_color = tf.keras.layers.Dense(len(color_label_names),
                                  activation="softmax",
                                  name="out_color")(x1)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# ERROR! Session/line number was not unique in database. History logging moved to new session 94
# Traceback (most recent call last):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3444, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_27322/693946441.py", line 1, in <module>
#     x = mobile_net(inputs)  #输出形状是4维的
# NameError: name 'mobile_net' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2064, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'NameError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/tensorflow/__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/tensorflow/__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.estimator'
# Traceback (most recent call last):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3444, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_27322/693946441.py", line 1, in <module>
#     x = mobile_net(inputs)  #输出形状是4维的
# NameError: name 'mobile_net' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2064, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'NameError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3364, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3461, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2067, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1125, in structured_traceback
#     tb_offset)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2064, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/tensorflow/__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/tensorflow/__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.estimator'
# Traceback (most recent call last):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3444, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_27322/693946441.py", line 1, in <module>
#     x = mobile_net(inputs)  #输出形状是4维的
# NameError: name 'mobile_net' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2064, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'NameError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3364, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3461, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2067, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1125, in structured_traceback
#     tb_offset)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2064, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2947, in _run_cell
#     return runner(coro)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3173, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3383, in run_ast_nodes
#     self.showtraceback()
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2067, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1143, in structured_traceback
#     chained_exceptions_tb_offset)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2064, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/tensorflow/__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/tensorflow/__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.estimator'

# %%
x2 = tf.keras.layers.Dense(1024,activation="relu")(x)
out_item = tf.keras.layers.Dense(len(item_label_names),
                                 activation="softmax",
                                name="out_item")(x1)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3444, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_27322/3103631061.py", line 1, in <module>
#     x2 = tf.keras.layers.Dense(1024,activation="relu")(x)
# NameError: name 'x' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2064, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'NameError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/tensorflow/__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/tensorflow/__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.estimator'
# Traceback (most recent call last):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3444, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_27322/3103631061.py", line 1, in <module>
#     x2 = tf.keras.layers.Dense(1024,activation="relu")(x)
# NameError: name 'x' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2064, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'NameError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3364, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3461, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2067, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1125, in structured_traceback
#     tb_offset)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2064, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/tensorflow/__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/tensorflow/__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.estimator'
# Traceback (most recent call last):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3444, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_27322/3103631061.py", line 1, in <module>
#     x2 = tf.keras.layers.Dense(1024,activation="relu")(x)
# NameError: name 'x' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2064, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'NameError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3364, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3461, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2067, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1125, in structured_traceback
#     tb_offset)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2064, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2947, in _run_cell
#     return runner(coro)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3173, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3383, in run_ast_nodes
#     self.showtraceback()
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2067, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1143, in structured_traceback
#     chained_exceptions_tb_offset)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2064, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/tensorflow/__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/tensorflow/__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.estimator'
# ERROR! Session/line number was not unique in database. History logging moved to new session 98

# %%
model = tf.keras.Model(inputs=inputs,outputs=[out_color,out_item])
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3444, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_27322/3004506285.py", line 1, in <module>
#     model = tf.keras.Model(inputs=inputs,outputs=[out_color,out_item])
# NameError: name 'out_color' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2064, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'NameError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/tensorflow/__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/tensorflow/__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.estimator'
# Traceback (most recent call last):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3444, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_27322/3004506285.py", line 1, in <module>
#     model = tf.keras.Model(inputs=inputs,outputs=[out_color,out_item])
# NameError: name 'out_color' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2064, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'NameError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3364, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3461, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2067, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1125, in structured_traceback
#     tb_offset)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2064, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/tensorflow/__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/tensorflow/__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.estimator'
# Traceback (most recent call last):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3444, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_27322/3004506285.py", line 1, in <module>
#     model = tf.keras.Model(inputs=inputs,outputs=[out_color,out_item])
# NameError: name 'out_color' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2064, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'NameError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3364, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3461, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2067, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1125, in structured_traceback
#     tb_offset)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2064, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2947, in _run_cell
#     return runner(coro)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3173, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3383, in run_ast_nodes
#     self.showtraceback()
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2067, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1368, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1268, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1143, in structured_traceback
#     chained_exceptions_tb_offset)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2064, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/tensorflow/__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/tensorflow/__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.estimator'
# ERROR! Session/line number was not unique in database. History logging moved to new session 100

# %%
model.summary()

# %%
model.compile(optimizer="adam",
             loss={"out_color":"sparse_categorical_crossentropy",
                  "out_item":"sparse_categorical_crossentropy"}
             metrics=["acc"])

# %%
train_steps = train_count//BATCH_SIZE
test_steps = test_count//BATCH_SIZE

# %%
model.fit(train_data,
         epochs=15,
         steps_per_epoch = train_steps,
         validation_data = test_data,
         validation_steps= test_steps)

# %%
#模型的评价
model.evaluadte(test_image_array,[test_color_labels,test_item_labels],verbose=0)

# %%
my_image = preprocess_image(r"")

# %%
my_image.shape

# %%
my_image = np.expand_dims(my_image,0) #扩展维度 满足输入格式要求

# %%
my_image.shape

# %%
#预测
pre = model.predict(my_image)

# %%
pre[0]
pre[1]

# %%
pre_color = np.argmax(pre[0][0])

# %%
pre_color = index_to_color.get(np.argmax(pre[0][0]))

# %%
pre_item = index_to_item.get(np.argmax(pre[1][0]))

# %%
#画出图片
my_image[0].shape   #4维变成1维

# %%
my_image[0]+1/2  #反归一化  才能画出图片

# %%
pred = pred_color +"_"+ pre_item

# %%
plt.imshow(my_image[0]+1/2)
plt.xlabel(pred)

# %%
#多找几个预测下数据  随即从test里找几个

# %%
my_image = preprocess_image(r"{}".format(random.choice(test_dir)))
