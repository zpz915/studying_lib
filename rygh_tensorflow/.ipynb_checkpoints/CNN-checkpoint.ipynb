# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow_core.python.keras import layers

# %matplotlib inline
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 42

# %%
fashion_mnist = keras.datasets.fashion_mnist
(train_images,train_labels),(test_images,test_labels)= fashion_mnist.load_data()
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 43

# %%
model = tf.keras.Sequential()
model.add(tf.keras.layers.Conv2D(32,(3,3),input_shape=(28,28,1),activation="relu"))
# Out:
# 2021-11-15 14:49:26.003550: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2021-11-15 14:49:26.003569: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-11-15 14:49:26.003602: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (mi-HP-ProDesk-680-G6-PCI-Microtower-PC): /proc/driver/nvidia/version does not exist
# 2021-11-15 14:49:26.003732: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# 2021-11-15 14:49:26.024234: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2899885000 Hz
# ...

# %%
model.output_shape  #32卷  默认不padding
# Out:
# (None, 26, 26, 32)

# %%
model = tf.keras.Sequential()
model.add(tf.keras.layers.Conv2D(32,(3,3),input_shape=(28,28,1),activation="relu",padding="same"))

# %%
model.output_shape
# Out:
# (None, 28, 28, 32)

# %%
model.add(tf.keras.layers.MaxPool2D()) #默认缩小一半

# %%
model.output_shape
# Out:
# (None, 14, 14, 32)

# %%
model.add(tf.keras.layers.Conv2D(64,(3,3),activation="relu"))

# %%
model.output_shape
# Out:
# (None, 12, 12, 64)

# %%
model.add(tf.keras.layers.GlobalAveragePooling2D())#全居池化  在所有纬度上进行平均 这样方便一会dense层连接 因为dense层值接受2维  而一般的flatten 效果不是很理想
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3444, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_9431/4014305924.py", line 1, in <module>
#     model.add(tf.keras.layers.GlobalAveragePooling2D())#全居池化  在所有纬度上进行平均 这样方便一会dense层连接 因为dense层值接受2维  而一般的flatten 效果不是很理想
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/tensorflow_core/python/training/tracking/base.py", line 457, in _method_wrapper
#     result = method(self, *args, **kwargs)
# ...

# %%
model.output_shape
# Out:
# (None, 64)
# ERROR! Session/line number was not unique in database. History logging moved to new session 45

# %%
#kaggle跑完后 优化的模型  添加了参数增加拟合能力 同时失活 防止过拟合

model = tf.keras.Sequential()
model.add(tf.keras.layers.Conv2D(64,(3,3),input_shape=train_images.shape[1:],activation="relu",padding="same"))
model.add(tf.keras.layers.Conv2D(64,(3,3),activation="relu",padding="same"))
model.add(tf.keras.layers.MaxPool2D()) #默认缩小一半
model.add(tf.keras.layers.Dropout(0.5)) 
model.add(tf.keras.layers.Conv2D(128,(3,3),activation="relu",padding="same"))
model.add(tf.keras.layers.Conv2D(128,(3,3),activation="relu",padding="same"))
model.add(tf.keras.layers.MaxPool2D()) #默认缩小一半
model.add(tf.keras.layers.Dropout(0.5)) 
model.add(tf.keras.layers.Conv2D(256,(3,3),activation="relu",padding="same"))
model.add(tf.keras.layers.Conv2D(256,(3,3),activation="relu",padding="same"))
model.add(tf.keras.layers.MaxPool2D())
model.add(tf.keras.layers.Dropout(0.5)) 
model.add(tf.keras.layers.Conv2D(512,(3,3),activation="relu",padding="same"))
model.add(tf.keras.layers.Conv2D(512,(3,3),activation="relu",padding="same"))
model.add(tf.keras.layers.Dropout(0.5)) 
model.add(tf.keras.layers.GlobalAveragePooling2D())#全居池化
model.add(tf.keras.layers.Dense(256,activation="relu"))
model.add(tf.keras.layers.Dense(10,activation="softmax"))
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3444, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_9431/3790734560.py", line 4, in <module>
#     model.add(tf.keras.layers.Conv2D(64,(3,3),input_shape=train_images.shape[1:],activation="relu",padding="same"))
#   File "/home/mi/zpz/anaconda3/envs/tf_2.0_gpu/lib/python3.7/site-packages/tensorflow_core/python/training/tracking/base.py", line 457, in _method_wrapper
#     result = method(self, *args, **kwargs)
# ...

# %%
#kaggle  GPU准确率提高很好
